# %%
import plotly as ply
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from matplotlib.patches import Arc
import numpy as np

import sklearn.linear_model as lm
from sklearn.model_selection import train_test_split

from haversine import haversine

# %%
df_cameras = pd.read_csv('cam_meta_rev1.csv')

# %%
df_cameras = df_cameras.loc[df_cameras['c_lat'] > 0]
del df_cameras['Unnamed: 13']

# %%
df_cameras
# Out:
#     Unnamed: 0       camera_id      lat  lat_decimals      long  \
# 1            1   hpwren1_north  33.1599             4 -116.8081
# 2            2    hpwren1_east  33.1599             4 -116.8081
# 3            3   hpwren1_south  33.1599             4 -116.8081
# 4            4    hpwren1_west  33.1599             4 -116.8081
# 5            5   hpwren2_north  32.9800             2 -117.1200
# ..         ...             ...      ...           ...       ...
# 84          84   hpwren26_east  33.6052             4 -117.8109
# 85          85  hpwren26_south  33.6052             4 -117.8109
# 86          86   hpwren26_west  33.6052             4 -117.8109
# 87          87  hpwren27_north  33.3787             4 -116.6223
# 89          89  hpwren27_south  33.3787             4 -116.6223
#
#         camera_name hpweren_camera_description  lat_adjusted  long_adjusted  \
# 1       bm-n-mobo-c         Big Black Mountain     33.159925    -116.808081
# 2       bm-e-mobo-c         Big Black Mountain     33.159925    -116.808081
# 3       bm-s-mobo-c         Big Black Mountain     33.159925    -116.808081
# 4       bm-w-mobo-c         Big Black Mountain     33.159925    -116.808081
# 5       bl-n-mobo-c             Black Mountain     32.981417    -117.116480
# ..              ...                        ...           ...            ...
# 84  signal-e-mobo-c                Signal Peak     33.605234    -117.810884
# 85  signal-s-mobo-c                Signal Peak     33.605234    -117.810884
# 86  signal-w-mobo-c                Signal Peak     33.605234    -117.810884
# 87    sojr-n-mobo-c                   Sky Oaks     33.378656    -116.622293
# 89    sojr-s-mobo-c                   Sky Oaks     33.378656    -116.622293
#
#       code dir      c_lat      c_long
# 1       bm   n  33.173626 -116.811270
# 2       bm   e  33.158781 -116.790230
# 3       bm   s  33.159596 -116.808061
# 4       bm   w  33.159091 -116.858706
# 5       bl   n  32.981788 -117.116520
# ..     ...  ..        ...         ...
# 84  signal   e  33.605323 -117.808562
# 85  signal   s  33.604231 -117.810847
# 86  signal   w  33.605237 -117.814578
# 87    sojr   n  33.385988 -116.622524
# 89    sojr   s  33.374521 -116.622139
#
# [73 rows x 13 columns]

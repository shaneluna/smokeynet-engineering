# %%
import pandas as pd
from haversine import haversine, Unit

# %%
lm_df = pd.read_csv("../data/landmarks_processed.csv")
cam_meta = pd.read_csv("../data/cam_meta_05302022.csv")

# %%
lm_df = lm_df.merge(cam_meta[['station', 'dir', 'cam_lat', 'cam_long']], left_on=['station', 'dir'], right_on=['station', 'dir'], how='left')
lm_df = lm_df.drop_duplicates().reset_index(drop=True)
lm_df['distance'] = lm_df.apply(lambda x: haversine((x['lat'], x['long']), (x['cam_lat'], x['cam_long'])), axis=1)
del lm_df['cam_lat']
del lm_df['cam_long']

# %%
lm_df
# Out:
#                                 landmark station dir        lat        long  \
# 0             white building - southwest      om   s  32.593892 -116.845919
# 1             white building - southwest      om   w  32.593892 -116.845919
# 2                 white building - south      om   s  32.594298 -116.844774
# 3    communication tower building - east      om   n  32.595487 -116.844141
# 4                             large bush      om   e  32.599053 -116.839254
# ..                                   ...     ...  ..        ...         ...
# 129       veritiv distribution warehouse     rdd   n  33.108108 -117.115555
# 130                mt laguna water tower     mlo   n  32.875975 -116.414988
# 131                     left observatory     mlo   n  32.840830 -116.427060
# 132                     tree cluster end      mg   w  33.182096 -116.781314
# 133                     tree cluster end      bm   n  33.182096 -116.781314
#
#      x_pixel  y_pixel  x_res  y_res  intersection  distance
# 0       2900     1715   3072   2048             0  0.150093
# 1        423     1685   3072   2048             0  0.150093
# 2       1780     1930   3072   2048             0  0.052190
# 3       2545     1725   3072   2048             0  0.095800
# 4        318     1420   3072   2048             0  0.698102
# ..       ...      ...    ...    ...           ...       ...
# 129     2078     1140   3072   2048             1  1.667744
# 130     1966     1055   3072   2048             1  4.177608
# 131      880     1290   3072   2048             0  0.138275
# 132      880     1388   3072   2048             1  2.063995
# 133     2800     1195   3072   2048             1  3.505396
#
# [134 rows x 11 columns]

# %%
lm_df.to_csv("../data/landmarks_processed.csv", index=False)

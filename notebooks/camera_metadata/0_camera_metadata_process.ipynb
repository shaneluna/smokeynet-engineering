# %% [markdown]
# # HPWREN Camera Metadata Process (Firemap API)

# %% [markdown]
# Summary: <br>
# The HPWREN camera metadata is stored within the San Diego Supercomputer Center and is accessible via the FireMap API.
#
# firemap api --> all cam metadata --> filter for hpwren only --> write to csv
#
# Open Questions: <br>
# - Are these active cameras only? (Are there ever historical cameras that are no longer active?)

# %% [markdown]
# ## Get All Camera Metadata From Firemap API

# %%
import json
from datetime import datetime

import pandas as pd
import pytz
import requests

# %%
BASE_URL = "https://firemap.sdsc.edu/pylaski/"

# %%
# Get data for ALL cameras
# https://firemap.sdsc.edu/pylaski/stations?camera=only&selection=boundingBox&minLat=0&maxLat=90&minLon=-180&maxLon=0
entity = "stations"
payload = {
    "camera": "only",
    "selection": "boundingBox",
    "minLat": 0,
    "maxLat": 90,  # northern hemisphere
    "minLon": -180,
    "maxLon": 0,  # western hemisphere
}
response = requests.get(f"{BASE_URL}{entity}", params=payload)

# %%
if response.status_code in range(200, 300):  # successful response range
    response_json = response.json()
    features = response_json["features"]
else:
    # TODO:
    # Add error handling
    print("Error!")

# %%
cameras_df = pd.json_normalize(features)
print(f"Total cameras: {len(cameras_df['properties.description.id'])}")
# Out:
# Total cameras: 1157

# %%
# cameras_df

# %%
# Camera breakdown
# all camera metadata either has hpwren or axis prefix
cameras_df["properties.description.id"].str.split(r"_|-", expand=True)[0].str.extract(
    r"([a-zA-Z]+)"
)[0].str.lower().value_counts()
# Out:
# axis      1054
# hpwren     103
# Name: 0, dtype: int64

# %% [markdown]
# ## Filter for HPWREN cameras only

# %%
# just get hpwren cameras (ignore axis)

hpwren_cameras_df = cameras_df[
    cameras_df["properties.description.id"]
    .str.lower()
    .str.contains("hpwren", regex=False)
].copy()

# dictoinary example below:
# hpwren_cameras = []
# for feat in features:
#     feat_id = feat["properties"]["description"]["id"]
#     if "hpwren" in feat_id.lower():
#         # print(feat_id)
#         hpwren_cameras.append(feat)

# %%
len(hpwren_cameras_df)
# Out:
# 103

# %% [markdown]
# ## Transformations

# %% [markdown]
# ### Extract direction

# %%
# Extract direction from description
hpwren_cameras_df["direction"] = hpwren_cameras_df[
    "properties.description.id"
].str.split("_", n=1, expand=True)[1]

# %%
hpwren_cameras_df["direction"].value_counts()
# Out:
# north                26
# east                 26
# south                25
# west                 25
# unknown direction     1
# Name: direction, dtype: int64

# %% [markdown]
# ### Extract image name

# %%
# image name
hpwren_cameras_df["image_id"] = (
    hpwren_cameras_df["properties.latest-images"]
    .str[0]
    .str[0]
    .str["image"]
    .str.split("/")
    .str[-1]
    .str.split(".")
    .str[0]
)

# %%
hpwren_cameras_df.shape
# Out:
# (103, 31)

# %%
hpwren_cameras_df.head()
# Out:
#       type geometry.type        geometry.coordinates  \
# 0  Feature         Point        [-117.12, 32.55, 10]
# 1  Feature         Point  [-116.8081, 33.1599, 4055]
# 2  Feature         Point  [-116.8081, 33.1599, 4055]
# 3  Feature         Point  [-116.8081, 33.1599, 4055]
# 4  Feature         Point  [-116.8081, 33.1599, 4055]
#
#   properties.description.name  properties.description.id  \
# 0                              hpwren0_unknown direction
# 1          Big Black Mountain              hpwren1_north
# 2          Big Black Mountain               hpwren1_east
# 3          Big Black Mountain              hpwren1_south
# 4          Big Black Mountain               hpwren1_west
#
#                       properties.description.url  \
# 0        http://hpwren.ucsd.edu/cameras/TJE.html
# 1  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 2  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 3  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 4  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
#
#                             properties.latest-images  \
# 0  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 1  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 2  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 3  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 4  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
#
#   properties.description.region  properties.description.is_patrol_mode  \
# 0                           NaN                                    NaN
# 1                           NaN                                    NaN
# 2                           NaN                                    NaN
# 3                           NaN                                    NaN
# 4                           NaN                                    NaN
#
#    properties.description.tilt_current  ... properties.description.network  \
# 0                                  NaN  ...                            NaN
# 1                                  NaN  ...                            NaN
# 2                                  NaN  ...                            NaN
# 3                                  NaN  ...                            NaN
# 4                                  NaN  ...                            NaN
#
#   properties.description.ProdNbr properties.description.isp  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
#
#   properties.description.fov_rt properties.description.lastupdate  \
# 0                           NaN                               NaN
# 1                           NaN                               NaN
# 2                           NaN                               NaN
# 3                           NaN                               NaN
# 4                           NaN                               NaN
#
#   properties.description.ptz  properties.description.az_current  \
# 0                        NaN                                NaN
# 1                        NaN                                NaN
# 2                        NaN                                NaN
# 3                        NaN                                NaN
# 4                        NaN                                NaN
#
#    properties.description.attribution          direction      image_id
# 0                                 NaN  unknown direction  tje-1-mobo-c
# 1                                 NaN              north   bm-n-mobo-c
# 2                                 NaN               east   bm-e-mobo-c
# 3                                 NaN              south   bm-s-mobo-c
# 4                                 NaN               west   bm-w-mobo-c
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Extract long, lat, elevation

# %%
hpwren_cameras_df["long"] = hpwren_cameras_df["geometry.coordinates"].str[0]
hpwren_cameras_df["lat"] = hpwren_cameras_df["geometry.coordinates"].str[1]
hpwren_cameras_df["elevation"] = hpwren_cameras_df["geometry.coordinates"].str[2]

# %%
hpwren_cameras_df.shape
# Out:
# (103, 34)

# %%
hpwren_cameras_df.head()
# Out:
#       type geometry.type        geometry.coordinates  \
# 0  Feature         Point        [-117.12, 32.55, 10]
# 1  Feature         Point  [-116.8081, 33.1599, 4055]
# 2  Feature         Point  [-116.8081, 33.1599, 4055]
# 3  Feature         Point  [-116.8081, 33.1599, 4055]
# 4  Feature         Point  [-116.8081, 33.1599, 4055]
#
#   properties.description.name  properties.description.id  \
# 0                              hpwren0_unknown direction
# 1          Big Black Mountain              hpwren1_north
# 2          Big Black Mountain               hpwren1_east
# 3          Big Black Mountain              hpwren1_south
# 4          Big Black Mountain               hpwren1_west
#
#                       properties.description.url  \
# 0        http://hpwren.ucsd.edu/cameras/TJE.html
# 1  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 2  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 3  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 4  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
#
#                             properties.latest-images  \
# 0  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 1  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 2  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 3  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 4  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
#
#   properties.description.region  properties.description.is_patrol_mode  \
# 0                           NaN                                    NaN
# 1                           NaN                                    NaN
# 2                           NaN                                    NaN
# 3                           NaN                                    NaN
# 4                           NaN                                    NaN
#
#    properties.description.tilt_current  ... properties.description.fov_rt  \
# 0                                  NaN  ...                           NaN
# 1                                  NaN  ...                           NaN
# 2                                  NaN  ...                           NaN
# 3                                  NaN  ...                           NaN
# 4                                  NaN  ...                           NaN
#
#   properties.description.lastupdate properties.description.ptz  \
# 0                               NaN                        NaN
# 1                               NaN                        NaN
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        NaN
#
#   properties.description.az_current properties.description.attribution  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#            direction      image_id      long      lat elevation
# 0  unknown direction  tje-1-mobo-c -117.1200  32.5500        10
# 1              north   bm-n-mobo-c -116.8081  33.1599      4055
# 2               east   bm-e-mobo-c -116.8081  33.1599      4055
# 3              south   bm-s-mobo-c -116.8081  33.1599      4055
# 4               west   bm-w-mobo-c -116.8081  33.1599      4055
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Merge with manually entered camera metadata
#
# - If manual data missing camera_name then merge
# - If manual data has camera_name then union

# %%
cam_man_df = pd.read_csv("../../data/raw/camera_metadata_manual.csv")
cam_man_df = cam_man_df.add_suffix("_manual")

# %%
cam_man_df.shape
# Out:
# (131, 9)

# %%
cam_man_df.head()
# Out:
#             camera_id_manual image_id_manual camera_name_manual  \
# 0  hpwren0_unknown direction             NaN                NaN
# 1              hpwren1_north             NaN                NaN
# 2               hpwren1_east             NaN                NaN
# 3              hpwren1_south             NaN                NaN
# 4               hpwren1_west             NaN                NaN
#
#   direction_manual  gmap_lat_manual  gmap_long_manual  elevation_manual  \
# 0              NaN              NaN               NaN               NaN
# 1              NaN        33.159927       -116.808092               NaN
# 2              NaN        33.159927       -116.808092               NaN
# 3              NaN        33.159927       -116.808092               NaN
# 4              NaN        33.159927       -116.808092               NaN
#
#    x_resolution_manual  y_resolution_manual
# 0                  NaN                  NaN
# 1               3072.0               2048.0
# 2               3072.0               2048.0
# 3               3072.0               2048.0
# 4               3072.0               2048.0

# %%
cam_man_na_df = cam_man_df[cam_man_df["camera_name_manual"].isna()]

# %%
cam_man_na_df.shape
# Out:
# (103, 9)

# %%
hpwren_cameras_df = hpwren_cameras_df.merge(
    cam_man_na_df,
    left_on="properties.description.id",
    right_on="camera_id_manual",
    how="inner",
)

# %%
hpwren_cameras_df.shape
# Out:
# (103, 43)

# %%
cam_man_nona_df = cam_man_df[~cam_man_df["camera_name_manual"].isna()]

# %%
cam_man_nona_df.shape
# Out:
# (28, 9)

# %%
hpwren_cameras_df = pd.concat([hpwren_cameras_df, cam_man_nona_df])

# %%
hpwren_cameras_df.shape
# Out:
# (131, 43)

# %%
hpwren_cameras_df.head()
# Out:
#       type geometry.type        geometry.coordinates  \
# 0  Feature         Point        [-117.12, 32.55, 10]
# 1  Feature         Point  [-116.8081, 33.1599, 4055]
# 2  Feature         Point  [-116.8081, 33.1599, 4055]
# 3  Feature         Point  [-116.8081, 33.1599, 4055]
# 4  Feature         Point  [-116.8081, 33.1599, 4055]
#
#   properties.description.name  properties.description.id  \
# 0                              hpwren0_unknown direction
# 1          Big Black Mountain              hpwren1_north
# 2          Big Black Mountain               hpwren1_east
# 3          Big Black Mountain              hpwren1_south
# 4          Big Black Mountain               hpwren1_west
#
#                       properties.description.url  \
# 0        http://hpwren.ucsd.edu/cameras/TJE.html
# 1  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 2  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 3  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 4  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
#
#                             properties.latest-images  \
# 0  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 1  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 2  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 3  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 4  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
#
#   properties.description.region  properties.description.is_patrol_mode  \
# 0                           NaN                                    NaN
# 1                           NaN                                    NaN
# 2                           NaN                                    NaN
# 3                           NaN                                    NaN
# 4                           NaN                                    NaN
#
#    properties.description.tilt_current  ... elevation  \
# 0                                  NaN  ...      10.0
# 1                                  NaN  ...    4055.0
# 2                                  NaN  ...    4055.0
# 3                                  NaN  ...    4055.0
# 4                                  NaN  ...    4055.0
#
#             camera_id_manual image_id_manual camera_name_manual  \
# 0  hpwren0_unknown direction             NaN                NaN
# 1              hpwren1_north             NaN                NaN
# 2               hpwren1_east             NaN                NaN
# 3              hpwren1_south             NaN                NaN
# 4               hpwren1_west             NaN                NaN
#
#   direction_manual gmap_lat_manual  gmap_long_manual  elevation_manual  \
# 0              NaN             NaN               NaN               NaN
# 1              NaN       33.159927       -116.808092               NaN
# 2              NaN       33.159927       -116.808092               NaN
# 3              NaN       33.159927       -116.808092               NaN
# 4              NaN       33.159927       -116.808092               NaN
#
#    x_resolution_manual y_resolution_manual
# 0                  NaN                 NaN
# 1               3072.0              2048.0
# 2               3072.0              2048.0
# 3               3072.0              2048.0
# 4               3072.0              2048.0
#
# [5 rows x 43 columns]

# %%
# If original value null, then fill with new value

hpwren_cameras_df["camera_id"] = hpwren_cameras_df["properties.description.id"].fillna(
    hpwren_cameras_df["camera_id_manual"]
)

hpwren_cameras_df["camera_name"] = hpwren_cameras_df[
    "properties.description.name"
].fillna(hpwren_cameras_df["camera_name_manual"])

hpwren_cameras_df["image_id"] = hpwren_cameras_df["image_id"].fillna(
    hpwren_cameras_df["image_id_manual"]
)

hpwren_cameras_df["direction"] = hpwren_cameras_df["direction"].fillna(
    hpwren_cameras_df["direction_manual"]
)

hpwren_cameras_df["elevation"] = hpwren_cameras_df["elevation"].fillna(
    hpwren_cameras_df["elevation_manual"]
)

# If manual value null, then fill with orig value

hpwren_cameras_df["lat"] = hpwren_cameras_df["gmap_lat_manual"].fillna(
    hpwren_cameras_df["lat"]
)

hpwren_cameras_df["long"] = hpwren_cameras_df["gmap_long_manual"].fillna(
    hpwren_cameras_df["long"]
)

# %%
columns = [
    "camera_id",
    "direction",
    "camera_name",
    "image_id",
    "long",
    "lat",
    "elevation",
    "geometry.type",
    "geometry.coordinates",
    "x_resolution_manual",
    "y_resolution_manual",
    "properties.description.url",
    # "properties.latest-images",
]
hpwren_cameras_final_df = hpwren_cameras_df[columns]
hpwren_cameras_final_df
# Out:
#                      camera_id          direction         camera_name  \
# 0    hpwren0_unknown direction  unknown direction
# 1                hpwren1_north              north  Big Black Mountain
# 2                 hpwren1_east               east  Big Black Mountain
# 3                hpwren1_south              south  Big Black Mountain
# 4                 hpwren1_west               west  Big Black Mountain
# ..                         ...                ...                 ...
# 106                        NaN               west       Santiago Peak
# 127                        NaN              north          White Star
# 128                        NaN               east          White Star
# 129                        NaN              south          White Star
# 130                        NaN               west          White Star
#
#           image_id        long        lat  elevation geometry.type  \
# 0     tje-1-mobo-c -117.120000  32.550000       10.0         Point
# 1      bm-n-mobo-c -116.808092  33.159927     4055.0         Point
# 2      bm-e-mobo-c -116.808092  33.159927     4055.0         Point
# 3      bm-s-mobo-c -116.808092  33.159927     4055.0         Point
# 4      bm-w-mobo-c -116.808092  33.159927     4055.0         Point
# ..             ...         ...        ...        ...           ...
# 106  stgo-w-mobo-c -117.534115  33.711172     5669.0           NaN
# 127    ws-n-mobo-c -116.318014  32.647266     4000.0           NaN
# 128    ws-e-mobo-c -116.318014  32.647266     4000.0           NaN
# 129    ws-s-mobo-c -116.318014  32.647266     4000.0           NaN
# 130    ws-w-mobo-c -116.318014  32.647266     4000.0           NaN
#
#            geometry.coordinates  x_resolution_manual  y_resolution_manual  \
# 0          [-117.12, 32.55, 10]                  NaN                  NaN
# 1    [-116.8081, 33.1599, 4055]               3072.0               2048.0
# 2    [-116.8081, 33.1599, 4055]               3072.0               2048.0
# 3    [-116.8081, 33.1599, 4055]               3072.0               2048.0
# 4    [-116.8081, 33.1599, 4055]               3072.0               2048.0
# ..                          ...                  ...                  ...
# 106                         NaN               3072.0               2048.0
# 127                         NaN               3072.0               2048.0
# 128                         NaN               3072.0               2048.0
# 129                         NaN               3072.0               2048.0
# 130                         NaN               3072.0               2048.0
#
#                         properties.description.url
# 0          http://hpwren.ucsd.edu/cameras/TJE.html
# 1    http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 2    http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 3    http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 4    http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# ..                                             ...
# 106                                            NaN
# 127                                            NaN
# 128                                            NaN
# 129                                            NaN
# 130                                            NaN
#
# [131 rows x 12 columns]

# %% [markdown]
# ## Write camera metadata to raw and processed folders

# %%
# current_time_str = datetime.now(tz=pytz.UTC).strftime("%m/%d/%Y, %H:%M:%S")
current_time_str = datetime.now(tz=pytz.UTC).strftime("%Y%m%d_%H_%M_%S")

# all cameras
raw_output_path = f"../../data/raw/camera_metadata.csv"
cameras_df.to_csv(raw_output_path, index=False)

# hpwren cameras only
processed_output_path = f"../../data/processed/camera_metadata_hpwren.csv"
hpwren_cameras_final_df.to_csv(processed_output_path, index=False)

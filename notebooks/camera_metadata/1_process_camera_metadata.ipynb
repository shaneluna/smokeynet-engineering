# %% [markdown]
# # Process HPWREN Camera Metadata (Firemap API)

# %% [markdown]
# <b>Summary:</b><br>
# Processes the hpwren only camera metadata pulled from firemap pylaski api.
#
# - Read in raw camera metadata
# - Filter for HPWREN cameras only
# - Transform
#     - Extract direction as col
#     - Extract image name as col
#     - Extract lat, long, elevation as cols
#     - Merge with manually entered camera metadata
#     1. If manual data missing camera_name then merge (append/correct data)
#     2. If manual data has camera_name then union (add missing data)
# - Save processed hpwren camera metadata file
# - Calculate mapping of camera_id to image_ids
# - Save camera_id image_id mapping file
#
# <b>Output:</b><br>
# .<br>
# └── data<br>
# &emsp;&emsp;&emsp;└── processed<br>
# &emsp;&emsp;&emsp;&nbsp;&nbsp;&emsp;&emsp;&nbsp;└── camera_metadata_hpwren.csv<br>
# &emsp;&emsp;&emsp;&nbsp;&nbsp;&emsp;&emsp;&nbsp;└── camera_image_id_map.csv<br>
#
# <b>Areas for Improvement:</b><br>

# %% [markdown]
# ## Read All Camera Metadata

# %%
import json
from ast import literal_eval
from datetime import datetime

import pandas as pd
import pytz

# %%
# literal_eval to read columns as lists
cameras_df = pd.read_csv(
    "../../data/raw/camera_metadata.csv",
    converters={
        "geometry.coordinates": literal_eval,
        "properties.latest-images": literal_eval,
    },
)

# %%
cameras_df.head()
# Out:
#       type geometry.type        geometry.coordinates  \
# 0  Feature         Point        [-117.12, 32.55, 10]
# 1  Feature         Point  [-116.8081, 33.1599, 4055]
# 2  Feature         Point  [-116.8081, 33.1599, 4055]
# 3  Feature         Point  [-116.8081, 33.1599, 4055]
# 4  Feature         Point  [-116.8081, 33.1599, 4055]
#
#   properties.description.name  properties.description.id  \
# 0                         NaN  hpwren0_unknown direction
# 1          Big Black Mountain              hpwren1_north
# 2          Big Black Mountain               hpwren1_east
# 3          Big Black Mountain              hpwren1_south
# 4          Big Black Mountain               hpwren1_west
#
#                       properties.description.url  \
# 0        http://hpwren.ucsd.edu/cameras/TJE.html
# 1  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 2  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 3  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 4  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
#
#                             properties.latest-images  \
# 0  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 1  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 2  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 3  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 4  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
#
#   properties.description.type  properties.description.ptz  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    properties.description.zoom_current  ...  \
# 0                                  NaN  ...
# 1                                  NaN  ...
# 2                                  NaN  ...
# 3                                  NaN  ...
# 4                                  NaN  ...
#
#   properties.description.is_patrol_mode properties.description.lastupdate  \
# 0                                   NaN                               NaN
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3                                   NaN                               NaN
# 4                                   NaN                               NaN
#
#   properties.description.region properties.description.fov  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
#
#   properties.description.activated_at  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   properties.description.is_currently_patrolling  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   properties.description.az_current properties.description.state  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
#
#   properties.description.fov_rt  properties.description.tilt_current
# 0                           NaN                                  NaN
# 1                           NaN                                  NaN
# 2                           NaN                                  NaN
# 3                           NaN                                  NaN
# 4                           NaN                                  NaN
#
# [5 rows x 29 columns]

# %%
# Camera breakdown
# all camera metadata either has hpwren or axis prefix
cameras_df["properties.description.id"].str.split(r"_|-", expand=True)[0].str.extract(
    r"([a-zA-Z]+)"
)[0].str.lower().value_counts()
# Out:
# axis      1055
# hpwren     103
# Name: 0, dtype: int64

# %% [markdown]
# ## Filter for HPWREN cameras only

# %%
# just get hpwren cameras (ignore axis)

hpwren_cameras_df = cameras_df[
    cameras_df["properties.description.id"]
    .str.lower()
    .str.contains("hpwren", regex=False)
].copy()

# dictoinary example below:
# hpwren_cameras = []
# for feat in features:
#     feat_id = feat["properties"]["description"]["id"]
#     if "hpwren" in feat_id.lower():
#         # print(feat_id)
#         hpwren_cameras.append(feat)

# %%
len(hpwren_cameras_df)
# Out:
# 103

# %% [markdown]
# ## Transformations

# %% [markdown]
# ### Extract direction

# %%
# Extract direction from description
hpwren_cameras_df["direction"] = hpwren_cameras_df[
    "properties.description.id"
].str.split("_", n=1, expand=True)[1]

# %%
hpwren_cameras_df["direction"].value_counts()
# Out:
# north                26
# east                 26
# south                25
# west                 25
# unknown direction     1
# Name: direction, dtype: int64

# %% [markdown]
# ### Extract image name

# %%
# image name
hpwren_cameras_df["image_id"] = (
    hpwren_cameras_df["properties.latest-images"]
    .str[0]
    .str[0]
    .str["image"]
    .str.split("/")
    .str[-1]
    .str.split(".")
    .str[0]
)

# %%
hpwren_cameras_df.shape
# Out:
# (103, 31)

# %%
hpwren_cameras_df.head()
# Out:
#       type geometry.type        geometry.coordinates  \
# 0  Feature         Point        [-117.12, 32.55, 10]
# 1  Feature         Point  [-116.8081, 33.1599, 4055]
# 2  Feature         Point  [-116.8081, 33.1599, 4055]
# 3  Feature         Point  [-116.8081, 33.1599, 4055]
# 4  Feature         Point  [-116.8081, 33.1599, 4055]
#
#   properties.description.name  properties.description.id  \
# 0                         NaN  hpwren0_unknown direction
# 1          Big Black Mountain              hpwren1_north
# 2          Big Black Mountain               hpwren1_east
# 3          Big Black Mountain              hpwren1_south
# 4          Big Black Mountain               hpwren1_west
#
#                       properties.description.url  \
# 0        http://hpwren.ucsd.edu/cameras/TJE.html
# 1  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 2  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 3  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 4  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
#
#                             properties.latest-images  \
# 0  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 1  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 2  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 3  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 4  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
#
#   properties.description.type  properties.description.ptz  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    properties.description.zoom_current  ... properties.description.region  \
# 0                                  NaN  ...                           NaN
# 1                                  NaN  ...                           NaN
# 2                                  NaN  ...                           NaN
# 3                                  NaN  ...                           NaN
# 4                                  NaN  ...                           NaN
#
#   properties.description.fov properties.description.activated_at  \
# 0                        NaN                                 NaN
# 1                        NaN                                 NaN
# 2                        NaN                                 NaN
# 3                        NaN                                 NaN
# 4                        NaN                                 NaN
#
#   properties.description.is_currently_patrolling  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   properties.description.az_current properties.description.state  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
#
#   properties.description.fov_rt properties.description.tilt_current  \
# 0                           NaN                                 NaN
# 1                           NaN                                 NaN
# 2                           NaN                                 NaN
# 3                           NaN                                 NaN
# 4                           NaN                                 NaN
#
#            direction      image_id
# 0  unknown direction  tje-1-mobo-c
# 1              north   bm-n-mobo-c
# 2               east   bm-e-mobo-c
# 3              south   bm-s-mobo-c
# 4               west   bm-w-mobo-c
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Extract long, lat, elevation

# %%
hpwren_cameras_df["long"] = hpwren_cameras_df["geometry.coordinates"].str[0]
hpwren_cameras_df["lat"] = hpwren_cameras_df["geometry.coordinates"].str[1]
hpwren_cameras_df["elevation"] = hpwren_cameras_df["geometry.coordinates"].str[2]

# %%
hpwren_cameras_df.shape
# Out:
# (103, 34)

# %%
hpwren_cameras_df.head()
# Out:
#       type geometry.type        geometry.coordinates  \
# 0  Feature         Point        [-117.12, 32.55, 10]
# 1  Feature         Point  [-116.8081, 33.1599, 4055]
# 2  Feature         Point  [-116.8081, 33.1599, 4055]
# 3  Feature         Point  [-116.8081, 33.1599, 4055]
# 4  Feature         Point  [-116.8081, 33.1599, 4055]
#
#   properties.description.name  properties.description.id  \
# 0                         NaN  hpwren0_unknown direction
# 1          Big Black Mountain              hpwren1_north
# 2          Big Black Mountain               hpwren1_east
# 3          Big Black Mountain              hpwren1_south
# 4          Big Black Mountain               hpwren1_west
#
#                       properties.description.url  \
# 0        http://hpwren.ucsd.edu/cameras/TJE.html
# 1  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 2  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 3  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 4  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
#
#                             properties.latest-images  \
# 0  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 1  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 2  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 3  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 4  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
#
#   properties.description.type  properties.description.ptz  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    properties.description.zoom_current  ...  \
# 0                                  NaN  ...
# 1                                  NaN  ...
# 2                                  NaN  ...
# 3                                  NaN  ...
# 4                                  NaN  ...
#
#   properties.description.is_currently_patrolling  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   properties.description.az_current properties.description.state  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
#
#   properties.description.fov_rt properties.description.tilt_current  \
# 0                           NaN                                 NaN
# 1                           NaN                                 NaN
# 2                           NaN                                 NaN
# 3                           NaN                                 NaN
# 4                           NaN                                 NaN
#
#            direction      image_id      long      lat  elevation
# 0  unknown direction  tje-1-mobo-c -117.1200  32.5500         10
# 1              north   bm-n-mobo-c -116.8081  33.1599       4055
# 2               east   bm-e-mobo-c -116.8081  33.1599       4055
# 3              south   bm-s-mobo-c -116.8081  33.1599       4055
# 4               west   bm-w-mobo-c -116.8081  33.1599       4055
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Merge with manually entered camera metadata
#
# - If manual data missing camera_name then merge
# - If manual data has camera_name then union

# %%
cam_man_df = pd.read_csv(
    "../../data/raw/camera_metadata_manual.csv",
    converters={"prev_image_ids": lambda x: x.strip("[]").split(", ")},
)
cam_man_df = cam_man_df.add_suffix("_manual")

# %%
cam_man_df.shape
# Out:
# (138, 12)

# %%
cam_man_df.head()
# Out:
#             camera_id_manual image_id_manual prev_image_ids_manual  \
# 0  hpwren0_unknown direction             NaN                    []
# 1              hpwren1_north             NaN                    []
# 2               hpwren1_east             NaN                    []
# 3              hpwren1_south             NaN                    []
# 4               hpwren1_west             NaN                    []
#
#   camera_name_manual direction_manual  gmap_lat_manual  gmap_long_manual  \
# 0                NaN              NaN              NaN               NaN
# 1                NaN              NaN        33.159927       -116.808092
# 2                NaN              NaN        33.159927       -116.808092
# 3                NaN              NaN        33.159927       -116.808092
# 4                NaN              NaN        33.159927       -116.808092
#
#    elevation_manual  x_resolution_manual  y_resolution_manual  \
# 0               NaN                  NaN                  NaN
# 1               NaN               3072.0               2048.0
# 2               NaN               3072.0               2048.0
# 3               NaN               3072.0               2048.0
# 4               NaN               3072.0               2048.0
#
#    center_lat_manual  center_long_manual
# 0                NaN                 NaN
# 1          33.181599         -116.807554
# 2          33.158781         -116.790230
# 3          33.157932         -116.807962
# 4          33.159091         -116.858706

# %%
cam_man_na_df = cam_man_df[cam_man_df["camera_name_manual"].isna()]

# %%
cam_man_na_df.shape
# Out:
# (103, 12)

# %%
hpwren_cameras_df = hpwren_cameras_df.merge(
    cam_man_na_df,
    left_on="properties.description.id",
    right_on="camera_id_manual",
    how="inner",
)

# %%
hpwren_cameras_df.shape
# Out:
# (103, 46)

# %%
cam_man_nona_df = cam_man_df[~cam_man_df["camera_name_manual"].isna()]

# %%
cam_man_nona_df.shape
# Out:
# (35, 12)

# %%
hpwren_cameras_df = pd.concat([hpwren_cameras_df, cam_man_nona_df])

# %%
hpwren_cameras_df.shape
# Out:
# (138, 46)

# %%
hpwren_cameras_df.head()
# Out:
#       type geometry.type        geometry.coordinates  \
# 0  Feature         Point        [-117.12, 32.55, 10]
# 1  Feature         Point  [-116.8081, 33.1599, 4055]
# 2  Feature         Point  [-116.8081, 33.1599, 4055]
# 3  Feature         Point  [-116.8081, 33.1599, 4055]
# 4  Feature         Point  [-116.8081, 33.1599, 4055]
#
#   properties.description.name  properties.description.id  \
# 0                         NaN  hpwren0_unknown direction
# 1          Big Black Mountain              hpwren1_north
# 2          Big Black Mountain               hpwren1_east
# 3          Big Black Mountain              hpwren1_south
# 4          Big Black Mountain               hpwren1_west
#
#                       properties.description.url  \
# 0        http://hpwren.ucsd.edu/cameras/TJE.html
# 1  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 2  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 3  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 4  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
#
#                             properties.latest-images  \
# 0  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 1  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 2  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 3  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 4  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
#
#   properties.description.type  properties.description.ptz  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    properties.description.zoom_current  ... prev_image_ids_manual  \
# 0                                  NaN  ...                    []
# 1                                  NaN  ...                    []
# 2                                  NaN  ...                    []
# 3                                  NaN  ...                    []
# 4                                  NaN  ...                    []
#
#   camera_name_manual direction_manual gmap_lat_manual gmap_long_manual  \
# 0                NaN              NaN             NaN              NaN
# 1                NaN              NaN       33.159927      -116.808092
# 2                NaN              NaN       33.159927      -116.808092
# 3                NaN              NaN       33.159927      -116.808092
# 4                NaN              NaN       33.159927      -116.808092
#
#   elevation_manual x_resolution_manual y_resolution_manual center_lat_manual  \
# 0              NaN                 NaN                 NaN               NaN
# 1              NaN              3072.0              2048.0         33.181599
# 2              NaN              3072.0              2048.0         33.158781
# 3              NaN              3072.0              2048.0         33.157932
# 4              NaN              3072.0              2048.0         33.159091
#
#    center_long_manual
# 0                 NaN
# 1         -116.807554
# 2         -116.790230
# 3         -116.807962
# 4         -116.858706
#
# [5 rows x 46 columns]

# %%
# If original value null, then fill with new value

hpwren_cameras_df["camera_id"] = hpwren_cameras_df["properties.description.id"].fillna(
    hpwren_cameras_df["camera_id_manual"]
)

hpwren_cameras_df["camera_name"] = hpwren_cameras_df[
    "properties.description.name"
].fillna(hpwren_cameras_df["camera_name_manual"])

hpwren_cameras_df["image_id"] = hpwren_cameras_df["image_id"].fillna(
    hpwren_cameras_df["image_id_manual"]
)

hpwren_cameras_df["direction"] = hpwren_cameras_df["direction"].fillna(
    hpwren_cameras_df["direction_manual"]
)

hpwren_cameras_df["elevation"] = hpwren_cameras_df["elevation"].fillna(
    hpwren_cameras_df["elevation_manual"]
)

# If manual value null, then fill with orig value

hpwren_cameras_df["lat"] = hpwren_cameras_df["gmap_lat_manual"].fillna(
    hpwren_cameras_df["lat"]
)

hpwren_cameras_df["long"] = hpwren_cameras_df["gmap_long_manual"].fillna(
    hpwren_cameras_df["long"]
)

# %%
columns = [
    "camera_id",
    "direction",
    "camera_name",
    "image_id",
    "prev_image_ids_manual",
    "long",
    "lat",
    "elevation",
    "geometry.type",
    "geometry.coordinates",
    "x_resolution_manual",
    "y_resolution_manual",
    "center_lat_manual",
    "center_long_manual",
    "properties.description.url",
    # "properties.latest-images",
]
hpwren_cameras_final_df = hpwren_cameras_df[columns]

hpwren_cameras_final_df = hpwren_cameras_final_df.rename(
    columns={
        "prev_image_ids_manual": "prev_image_ids",
        "x_resolution_manual": "x_resolution",
        "y_resolution_manual": "y_resolution",
        "center_lat_manual": "center_lat",
        "center_long_manual": "center_long",
    },
)

hpwren_cameras_final_df
# Out:
#                      camera_id          direction         camera_name  \
# 0    hpwren0_unknown direction  unknown direction                 NaN
# 1                hpwren1_north              north  Big Black Mountain
# 2                 hpwren1_east               east  Big Black Mountain
# 3                hpwren1_south              south  Big Black Mountain
# 4                 hpwren1_west               west  Big Black Mountain
# ..                         ...                ...                 ...
# 133      hpwren_missing7_south              south    SMER TCS9 HPWREN
# 134       hpwren_missing7_west               west    SMER TCS9 HPWREN
# 135       hpwren_missing8_west               east    SMER TCS3 HPWREN
# 136       hpwren_missing9_west               west    SMER TCS8 HPWREN
# 137      hpwren_missing10_west          southeast   SMER TCS10 HPWREN
#
#                image_id       prev_image_ids        long        lat  \
# 0          tje-1-mobo-c                   [] -117.120000  32.550000
# 1           bm-n-mobo-c                   [] -116.808092  33.159927
# 2           bm-e-mobo-c                   [] -116.808092  33.159927
# 3           bm-s-mobo-c                   [] -116.808092  33.159927
# 4           bm-w-mobo-c                   [] -116.808092  33.159927
# ..                  ...                  ...         ...        ...
# 133  smer-tcs9-s-mobo-c                   [] -117.530000  33.710000
# 134  smer-tcs9-w-mobo-c   [smer-tcs9-mobo-c] -117.530000  33.710000
# 135    smer-tcs3-mobo-c   [smer-tcs3-mobo-c] -117.180000  33.450000
# 136    smer-tcs8-mobo-c   [smer-tcs8-mobo-c] -117.150000  33.460000
# 137   smer-tcs10-mobo-c  [smer-tcs10-mobo-c] -117.140000  33.460000
#
#      elevation geometry.type        geometry.coordinates  x_resolution  \
# 0         10.0         Point        [-117.12, 32.55, 10]           NaN
# 1       4055.0         Point  [-116.8081, 33.1599, 4055]        3072.0
# 2       4055.0         Point  [-116.8081, 33.1599, 4055]        3072.0
# 3       4055.0         Point  [-116.8081, 33.1599, 4055]        3072.0
# 4       4055.0         Point  [-116.8081, 33.1599, 4055]        3072.0
# ..         ...           ...                         ...           ...
# 133     5669.0           NaN                         NaN           NaN
# 134     5669.0           NaN                         NaN           NaN
# 135     1400.0           NaN                         NaN           NaN
# 136     2063.0           NaN                         NaN           NaN
# 137     2066.0           NaN                         NaN           NaN
#
#      y_resolution  center_lat  center_long  \
# 0             NaN         NaN          NaN
# 1          2048.0   33.181599  -116.807554
# 2          2048.0   33.158781  -116.790230
# 3          2048.0   33.157932  -116.807962
# 4          2048.0   33.159091  -116.858706
# ..            ...         ...          ...
# 133           NaN         NaN          NaN
# 134           NaN         NaN          NaN
# 135           NaN         NaN          NaN
# 136           NaN         NaN          NaN
# 137           NaN         NaN          NaN
#
#                         properties.description.url
# 0          http://hpwren.ucsd.edu/cameras/TJE.html
# 1    http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 2    http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 3    http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 4    http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# ..                                             ...
# 133                                            NaN
# 134                                            NaN
# 135                                            NaN
# 136                                            NaN
# 137                                            NaN
#
# [138 rows x 15 columns]

# %% [markdown]
# ## Write camera metadata to raw and processed folders

# %%
# current_time_str = datetime.now(tz=pytz.UTC).strftime("%Y%m%d_%H_%M_%S")

# hpwren cameras only
hpwren_cameras_final_df.to_csv(
    f"../../data/processed/camera_metadata_hpwren.csv", index=False
)

# %% [markdown]
# ## Normalize by the prev image_ids and write camera metadata to raw and processed folders

# %% [markdown]
# Accounts for the manual additional of previous image ids. I.e. If a camera link was renamed or need to be manually resolved.

# %%
# Create df of just the values that have previous ids

prev_image_ids_df = hpwren_cameras_final_df[
    hpwren_cameras_final_df["prev_image_ids"].str[0].str.len() > 0
].copy()

# explode in case multiple values
prev_image_ids_df = prev_image_ids_df[
    ["camera_id", "prev_image_ids", "lat", "long", "direction"]
].explode("prev_image_ids")

prev_image_ids_df = prev_image_ids_df.rename(columns={"prev_image_ids": "image_id"})

# %%
prev_image_ids_df
# Out:
#                  camera_id           image_id        lat        long  \
# 25           hpwren8_north          om-n-mobo  33.363018 -116.836220
# 26            hpwren8_east          om-e-mobo  33.363018 -116.836220
# 27           hpwren8_south          om-s-mobo  33.363018 -116.836220
# 28            hpwren8_west          om-w-mobo  33.363018 -116.836220
# 33          hpwren11_north          pi-n-mobo  32.734516 -116.577658
# 34           hpwren11_east          pi-e-mobo  32.734516 -116.577658
# 35          hpwren11_south          pi-s-mobo  32.734516 -116.577658
# 36           hpwren11_west          pi-w-mobo  32.734516 -116.577658
# 37          hpwren12_north          lp-n-mobo  32.701517 -116.764561
# 38           hpwren12_east          lp-e-mobo  32.701517 -116.764561
# 39          hpwren12_south          lp-s-mobo  32.701517 -116.764561
# 40           hpwren12_west          lp-w-mobo  32.701517 -116.764561
# 45          hpwren14_north        lo-n-mobo-c  32.892296 -116.420721
# 46           hpwren14_east        lo-e-mobo-c  32.892296 -116.420721
# 47          hpwren14_south        lo-s-mobo-c  32.892296 -116.420721
# 48           hpwren14_west        lo-w-mobo-c  32.892296 -116.420721
# 58          hpwren19_north        wc-n-mobo-c  33.008738 -116.970979
# 59           hpwren19_east        wc-e-mobo-c  33.008738 -116.970979
# 60          hpwren19_south        wc-s-mobo-c  33.008738 -116.970979
# 61           hpwren19_west        wc-w-mobo-c  33.008738 -116.970979
# 62          hpwren20_north          om-n-mobo  32.594762 -116.844694
# 63           hpwren20_east          om-e-mobo  32.594762 -116.844694
# 64          hpwren20_south          om-s-mobo  32.594762 -116.844694
# 65           hpwren20_west          om-w-mobo  32.594762 -116.844694
# 87          hpwren27_north        so-n-mobo-c  33.378656 -116.622293
# 88           hpwren27_east        so-e-mobo-c  33.378656 -116.622293
# 89          hpwren27_south        so-s-mobo-c  33.378656 -116.622293
# 90           hpwren27_west        so-w-mobo-c  33.378656 -116.622293
# 103  hpwren_missing5_north        sp-n-mobo-c  33.711172 -117.534115
# 104   hpwren_missing5_east        sp-e-mobo-c  33.711172 -117.534115
# 105  hpwren_missing5_south        sp-s-mobo-c  33.711172 -117.534115
# 106   hpwren_missing5_west        sp-w-mobo-c  33.711172 -117.534115
# 134   hpwren_missing7_west   smer-tcs9-mobo-c  33.710000 -117.530000
# 135   hpwren_missing8_west   smer-tcs3-mobo-c  33.450000 -117.180000
# 136   hpwren_missing9_west   smer-tcs8-mobo-c  33.460000 -117.150000
# 137  hpwren_missing10_west  smer-tcs10-mobo-c  33.460000 -117.140000
#
#      direction
# 25       north
# 26        east
# 27       south
# 28        west
# 33       north
# 34        east
# 35       south
# 36        west
# 37       north
# 38        east
# 39       south
# 40        west
# 45       north
# 46        east
# 47       south
# 48        west
# 58       north
# 59        east
# 60       south
# 61        west
# 62       north
# 63        east
# 64       south
# 65        west
# 87       north
# 88        east
# 89       south
# 90        west
# 103      north
# 104       east
# 105      south
# 106       west
# 134       west
# 135       east
# 136       west
# 137  southeast

# %%
# Grab original values

hpwren_cameras_final_copy_df = hpwren_cameras_final_df[
    ["camera_id", "image_id", "lat", "long", "direction"]
].copy()
hpwren_cameras_final_copy_df
# Out:
#                      camera_id            image_id        lat        long  \
# 0    hpwren0_unknown direction        tje-1-mobo-c  32.550000 -117.120000
# 1                hpwren1_north         bm-n-mobo-c  33.159927 -116.808092
# 2                 hpwren1_east         bm-e-mobo-c  33.159927 -116.808092
# 3                hpwren1_south         bm-s-mobo-c  33.159927 -116.808092
# 4                 hpwren1_west         bm-w-mobo-c  33.159927 -116.808092
# ..                         ...                 ...        ...         ...
# 133      hpwren_missing7_south  smer-tcs9-s-mobo-c  33.710000 -117.530000
# 134       hpwren_missing7_west  smer-tcs9-w-mobo-c  33.710000 -117.530000
# 135       hpwren_missing8_west    smer-tcs3-mobo-c  33.450000 -117.180000
# 136       hpwren_missing9_west    smer-tcs8-mobo-c  33.460000 -117.150000
# 137      hpwren_missing10_west   smer-tcs10-mobo-c  33.460000 -117.140000
#
#              direction
# 0    unknown direction
# 1                north
# 2                 east
# 3                south
# 4                 west
# ..                 ...
# 133              south
# 134               west
# 135               east
# 136               west
# 137          southeast
#
# [138 rows x 5 columns]

# %%
# Concat and drop dups for safety
hpwren_cameras_final_normalize_df = pd.concat(
    [hpwren_cameras_final_copy_df, prev_image_ids_df]
).drop_duplicates()

# %%
hpwren_cameras_final_normalize_df
# Out:
#                      camera_id          image_id        lat        long  \
# 0    hpwren0_unknown direction      tje-1-mobo-c  32.550000 -117.120000
# 1                hpwren1_north       bm-n-mobo-c  33.159927 -116.808092
# 2                 hpwren1_east       bm-e-mobo-c  33.159927 -116.808092
# 3                hpwren1_south       bm-s-mobo-c  33.159927 -116.808092
# 4                 hpwren1_west       bm-w-mobo-c  33.159927 -116.808092
# ..                         ...               ...        ...         ...
# 103      hpwren_missing5_north       sp-n-mobo-c  33.711172 -117.534115
# 104       hpwren_missing5_east       sp-e-mobo-c  33.711172 -117.534115
# 105      hpwren_missing5_south       sp-s-mobo-c  33.711172 -117.534115
# 106       hpwren_missing5_west       sp-w-mobo-c  33.711172 -117.534115
# 134       hpwren_missing7_west  smer-tcs9-mobo-c  33.710000 -117.530000
#
#              direction
# 0    unknown direction
# 1                north
# 2                 east
# 3                south
# 4                 west
# ..                 ...
# 103              north
# 104               east
# 105              south
# 106               west
# 134               west
#
# [171 rows x 5 columns]

# %%
hpwren_cameras_final_normalize_df.to_csv(
    f"../../data/processed/camera_image_id_mappings.csv", index=False
)

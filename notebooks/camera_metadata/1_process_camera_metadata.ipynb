# %% [markdown]
# # Process HPWREN Camera Metadata (Firemap API)

# %% [markdown]
# <b>Summary:</b><br>
# Processes the hpwren only camera metadata pulled from firemap pylaski api.
#
# <!-- - Get weather station metadata via synoptic api
# - Save raw weather station metadata file
# - Read in processed camera metadata
# - Filter out weather stations to ensure they have at least 1 years worth of data for time period
# - Map up to x stations to each camera
# - Save camera-to-stations mapping file
#  -->
# <b>Output:</b><br>
# .<br>
# └── data<br>
# &emsp;&emsp;&emsp;└── processed<br>
# &emsp;&emsp;&emsp;&nbsp;&nbsp;&emsp;&emsp;&nbsp;└── camera_metadata_hpwren.csv<br>
#
# <b>Areas for Improvement:</b><br>

# %% [markdown]
# ## Read All Camera Metadata

# %%
import json
from ast import literal_eval
from datetime import datetime

import pandas as pd
import numpy as np
import pytz
import geopandas
from shapely.geometry import Polygon, LineString, Point

# %%
# literal_eval to read columns as lists
cameras_df = pd.read_csv(
    "../../data/raw/camera_metadata.csv",
    converters={
        "geometry.coordinates": literal_eval,
        "properties.latest-images": literal_eval,
    },
)

# %%
cameras_df.head()
# Out:
#       type geometry.type        geometry.coordinates  \
# 0  Feature         Point        [-117.12, 32.55, 10]
# 1  Feature         Point  [-116.8081, 33.1599, 4055]
# 2  Feature         Point  [-116.8081, 33.1599, 4055]
# 3  Feature         Point  [-116.8081, 33.1599, 4055]
# 4  Feature         Point  [-116.8081, 33.1599, 4055]
#
#   properties.description.name  properties.description.id  \
# 0                         NaN  hpwren0_unknown direction
# 1          Big Black Mountain              hpwren1_north
# 2          Big Black Mountain               hpwren1_east
# 3          Big Black Mountain              hpwren1_south
# 4          Big Black Mountain               hpwren1_west
#
#                       properties.description.url  \
# 0        http://hpwren.ucsd.edu/cameras/TJE.html
# 1  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 2  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 3  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 4  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
#
#                             properties.latest-images  \
# 0  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 1  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 2  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 3  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 4  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
#
#   properties.description.type  properties.description.ptz  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    properties.description.zoom_current  ...  \
# 0                                  NaN  ...
# 1                                  NaN  ...
# 2                                  NaN  ...
# 3                                  NaN  ...
# 4                                  NaN  ...
#
#   properties.description.is_patrol_mode properties.description.lastupdate  \
# 0                                   NaN                               NaN
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3                                   NaN                               NaN
# 4                                   NaN                               NaN
#
#   properties.description.region properties.description.fov  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
#
#   properties.description.activated_at  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   properties.description.is_currently_patrolling  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   properties.description.az_current properties.description.state  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
#
#   properties.description.fov_rt  properties.description.tilt_current
# 0                           NaN                                  NaN
# 1                           NaN                                  NaN
# 2                           NaN                                  NaN
# 3                           NaN                                  NaN
# 4                           NaN                                  NaN
#
# [5 rows x 29 columns]

# %%
# Camera breakdown
# all camera metadata either has hpwren or axis prefix
cameras_df["properties.description.id"].str.split(r"_|-", expand=True)[0].str.extract(
    r"([a-zA-Z]+)"
)[0].str.lower().value_counts()
# Out:
# axis      1055
# hpwren     103
# Name: 0, dtype: int64

# %% [markdown]
# ## Filter for HPWREN cameras only

# %%
# just get hpwren cameras (ignore axis)

hpwren_cameras_df = cameras_df[
    cameras_df["properties.description.id"]
    .str.lower()
    .str.contains("hpwren", regex=False)
].copy()

# dictoinary example below:
# hpwren_cameras = []
# for feat in features:
#     feat_id = feat["properties"]["description"]["id"]
#     if "hpwren" in feat_id.lower():
#         # print(feat_id)
#         hpwren_cameras.append(feat)

# %%
len(hpwren_cameras_df)
# Out:
# 103

# %% [markdown]
# ## Transformations

# %% [markdown]
# ### Extract direction

# %%
# Extract direction from description
hpwren_cameras_df["direction"] = hpwren_cameras_df[
    "properties.description.id"
].str.split("_", n=1, expand=True)[1]

# %%
hpwren_cameras_df["direction"].value_counts()
# Out:
# north                26
# east                 26
# south                25
# west                 25
# unknown direction     1
# Name: direction, dtype: int64

# %% [markdown]
# ### Extract image name

# %%
# image name
hpwren_cameras_df["image_id"] = (
    hpwren_cameras_df["properties.latest-images"]
    .str[0]
    .str[0]
    .str["image"]
    .str.split("/")
    .str[-1]
    .str.split(".")
    .str[0]
)

# %%
hpwren_cameras_df.shape
# Out:
# (103, 31)

# %%
hpwren_cameras_df.head()
# Out:
#       type geometry.type        geometry.coordinates  \
# 0  Feature         Point        [-117.12, 32.55, 10]
# 1  Feature         Point  [-116.8081, 33.1599, 4055]
# 2  Feature         Point  [-116.8081, 33.1599, 4055]
# 3  Feature         Point  [-116.8081, 33.1599, 4055]
# 4  Feature         Point  [-116.8081, 33.1599, 4055]
#
#   properties.description.name  properties.description.id  \
# 0                         NaN  hpwren0_unknown direction
# 1          Big Black Mountain              hpwren1_north
# 2          Big Black Mountain               hpwren1_east
# 3          Big Black Mountain              hpwren1_south
# 4          Big Black Mountain               hpwren1_west
#
#                       properties.description.url  \
# 0        http://hpwren.ucsd.edu/cameras/TJE.html
# 1  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 2  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 3  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 4  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
#
#                             properties.latest-images  \
# 0  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 1  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 2  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 3  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 4  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
#
#   properties.description.type  properties.description.ptz  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    properties.description.zoom_current  ... properties.description.region  \
# 0                                  NaN  ...                           NaN
# 1                                  NaN  ...                           NaN
# 2                                  NaN  ...                           NaN
# 3                                  NaN  ...                           NaN
# 4                                  NaN  ...                           NaN
#
#   properties.description.fov properties.description.activated_at  \
# 0                        NaN                                 NaN
# 1                        NaN                                 NaN
# 2                        NaN                                 NaN
# 3                        NaN                                 NaN
# 4                        NaN                                 NaN
#
#   properties.description.is_currently_patrolling  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   properties.description.az_current properties.description.state  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
#
#   properties.description.fov_rt properties.description.tilt_current  \
# 0                           NaN                                 NaN
# 1                           NaN                                 NaN
# 2                           NaN                                 NaN
# 3                           NaN                                 NaN
# 4                           NaN                                 NaN
#
#            direction      image_id
# 0  unknown direction  tje-1-mobo-c
# 1              north   bm-n-mobo-c
# 2               east   bm-e-mobo-c
# 3              south   bm-s-mobo-c
# 4               west   bm-w-mobo-c
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Extract long, lat, elevation

# %%
hpwren_cameras_df["long"] = hpwren_cameras_df["geometry.coordinates"].str[0]
hpwren_cameras_df["lat"] = hpwren_cameras_df["geometry.coordinates"].str[1]
hpwren_cameras_df["elevation"] = hpwren_cameras_df["geometry.coordinates"].str[2]

# %%
hpwren_cameras_df.shape
# Out:
# (103, 34)

# %%
hpwren_cameras_df.head()
# Out:
#       type geometry.type        geometry.coordinates  \
# 0  Feature         Point        [-117.12, 32.55, 10]
# 1  Feature         Point  [-116.8081, 33.1599, 4055]
# 2  Feature         Point  [-116.8081, 33.1599, 4055]
# 3  Feature         Point  [-116.8081, 33.1599, 4055]
# 4  Feature         Point  [-116.8081, 33.1599, 4055]
#
#   properties.description.name  properties.description.id  \
# 0                         NaN  hpwren0_unknown direction
# 1          Big Black Mountain              hpwren1_north
# 2          Big Black Mountain               hpwren1_east
# 3          Big Black Mountain              hpwren1_south
# 4          Big Black Mountain               hpwren1_west
#
#                       properties.description.url  \
# 0        http://hpwren.ucsd.edu/cameras/TJE.html
# 1  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 2  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 3  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 4  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
#
#                             properties.latest-images  \
# 0  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 1  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 2  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 3  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 4  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
#
#   properties.description.type  properties.description.ptz  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    properties.description.zoom_current  ...  \
# 0                                  NaN  ...
# 1                                  NaN  ...
# 2                                  NaN  ...
# 3                                  NaN  ...
# 4                                  NaN  ...
#
#   properties.description.is_currently_patrolling  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   properties.description.az_current properties.description.state  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
#
#   properties.description.fov_rt properties.description.tilt_current  \
# 0                           NaN                                 NaN
# 1                           NaN                                 NaN
# 2                           NaN                                 NaN
# 3                           NaN                                 NaN
# 4                           NaN                                 NaN
#
#            direction      image_id      long      lat  elevation
# 0  unknown direction  tje-1-mobo-c -117.1200  32.5500         10
# 1              north   bm-n-mobo-c -116.8081  33.1599       4055
# 2               east   bm-e-mobo-c -116.8081  33.1599       4055
# 3              south   bm-s-mobo-c -116.8081  33.1599       4055
# 4               west   bm-w-mobo-c -116.8081  33.1599       4055
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Merge with manually entered camera metadata
#
# - If manual data missing camera_name then merge
# - If manual data has camera_name then union

# %%
cam_man_df = pd.read_csv("../../data/raw/camera_metadata_manual.csv")
cam_man_df = cam_man_df.add_suffix("_manual")

# %%
cam_man_df.shape
# Out:
# (131, 11)

# %%
cam_man_df.head()
# Out:
#             camera_id_manual image_id_manual camera_name_manual  \
# 0  hpwren0_unknown direction             NaN                NaN
# 1              hpwren1_north             NaN                NaN
# 2               hpwren1_east             NaN                NaN
# 3              hpwren1_south             NaN                NaN
# 4               hpwren1_west             NaN                NaN
#
#   direction_manual  gmap_lat_manual  gmap_long_manual  elevation_manual  \
# 0              NaN              NaN               NaN               NaN
# 1              NaN        33.159927       -116.808092               NaN
# 2              NaN        33.159927       -116.808092               NaN
# 3              NaN        33.159927       -116.808092               NaN
# 4              NaN        33.159927       -116.808092               NaN
#
#    x_resolution_manual  y_resolution_manual  center_lat_manual  \
# 0                  NaN                  NaN                NaN
# 1               3072.0               2048.0          33.181599
# 2               3072.0               2048.0          33.158781
# 3               3072.0               2048.0          33.157932
# 4               3072.0               2048.0          33.159091
#
#    center_long_manual
# 0                 NaN
# 1         -116.807554
# 2         -116.790230
# 3         -116.807962
# 4         -116.858706

# %%
cam_man_na_df = cam_man_df[cam_man_df["camera_name_manual"].isna()]

# %%
cam_man_na_df.shape
# Out:
# (103, 11)

# %%
hpwren_cameras_df = hpwren_cameras_df.merge(
    cam_man_na_df,
    left_on="properties.description.id",
    right_on="camera_id_manual",
    how="inner",
)

# %%
hpwren_cameras_df.shape
# Out:
# (103, 45)

# %%
cam_man_nona_df = cam_man_df[~cam_man_df["camera_name_manual"].isna()]

# %%
cam_man_nona_df.shape
# Out:
# (28, 11)

# %%
hpwren_cameras_df = pd.concat([hpwren_cameras_df, cam_man_nona_df])

# %%
hpwren_cameras_df.shape
# Out:
# (131, 45)

# %%
hpwren_cameras_df.head()
# Out:
#       type geometry.type        geometry.coordinates  \
# 0  Feature         Point        [-117.12, 32.55, 10]
# 1  Feature         Point  [-116.8081, 33.1599, 4055]
# 2  Feature         Point  [-116.8081, 33.1599, 4055]
# 3  Feature         Point  [-116.8081, 33.1599, 4055]
# 4  Feature         Point  [-116.8081, 33.1599, 4055]
#
#   properties.description.name  properties.description.id  \
# 0                         NaN  hpwren0_unknown direction
# 1          Big Black Mountain              hpwren1_north
# 2          Big Black Mountain               hpwren1_east
# 3          Big Black Mountain              hpwren1_south
# 4          Big Black Mountain               hpwren1_west
#
#                       properties.description.url  \
# 0        http://hpwren.ucsd.edu/cameras/TJE.html
# 1  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 2  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 3  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 4  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
#
#                             properties.latest-images  \
# 0  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 1  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 2  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 3  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
# 4  [[{'image': 'http://hpwren.ucsd.edu/cameras/L/...
#
#   properties.description.type  properties.description.ptz  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    properties.description.zoom_current  ... image_id_manual  \
# 0                                  NaN  ...             NaN
# 1                                  NaN  ...             NaN
# 2                                  NaN  ...             NaN
# 3                                  NaN  ...             NaN
# 4                                  NaN  ...             NaN
#
#   camera_name_manual direction_manual gmap_lat_manual gmap_long_manual  \
# 0                NaN              NaN             NaN              NaN
# 1                NaN              NaN       33.159927      -116.808092
# 2                NaN              NaN       33.159927      -116.808092
# 3                NaN              NaN       33.159927      -116.808092
# 4                NaN              NaN       33.159927      -116.808092
#
#   elevation_manual x_resolution_manual y_resolution_manual center_lat_manual  \
# 0              NaN                 NaN                 NaN               NaN
# 1              NaN              3072.0              2048.0         33.181599
# 2              NaN              3072.0              2048.0         33.158781
# 3              NaN              3072.0              2048.0         33.157932
# 4              NaN              3072.0              2048.0         33.159091
#
#    center_long_manual
# 0                 NaN
# 1         -116.807554
# 2         -116.790230
# 3         -116.807962
# 4         -116.858706
#
# [5 rows x 45 columns]

# %%
# If original value null, then fill with new value

hpwren_cameras_df["camera_id"] = hpwren_cameras_df["properties.description.id"].fillna(
    hpwren_cameras_df["camera_id_manual"]
)

hpwren_cameras_df["camera_name"] = hpwren_cameras_df[
    "properties.description.name"
].fillna(hpwren_cameras_df["camera_name_manual"])

hpwren_cameras_df["image_id"] = hpwren_cameras_df["image_id"].fillna(
    hpwren_cameras_df["image_id_manual"]
)

hpwren_cameras_df["direction"] = hpwren_cameras_df["direction"].fillna(
    hpwren_cameras_df["direction_manual"]
)

hpwren_cameras_df["elevation"] = hpwren_cameras_df["elevation"].fillna(
    hpwren_cameras_df["elevation_manual"]
)

# If manual value null, then fill with orig value

hpwren_cameras_df["lat"] = hpwren_cameras_df["gmap_lat_manual"].fillna(
    hpwren_cameras_df["lat"]
)

hpwren_cameras_df["long"] = hpwren_cameras_df["gmap_long_manual"].fillna(
    hpwren_cameras_df["long"]
)

# %% [markdown]
# ### Centerline Offset Angle Calculation & Camera Abbreviations

# %%
def find_cl_angle(ax, ay, bx, by, direction):
    a = np.array([ax, ay])
    b = np.array([bx, by])
    if direction.lower() in ['north', 'east', 'south', 'west']:
        if direction.lower() == 'north':
            cx = bx
            cy = by + 0.05
            if ax >= bx:
                sign = -1
            else:
                sign = 1
        if direction.lower() == 'east':
            cx = bx + 0.05
            cy = by
            if ay >= by:
                sign = 1
            else:
                sign = -1
        if direction.lower() == 'south':
            cx = bx
            cy = by - 0.05
            if ax >= bx:
                sign = 1
            else:
                sign = -1
        if direction.lower() == 'west':
            cx = bx - 0.05
            cy = by
            if ay >= by:
                sign = -1
            else:
                sign = 1

        c = np.array([cx, cy])

        ba = a - b
        bc = c - b

        cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
        angle = np.arccos(cosine_angle)
        return angle * sign
    else:
        return np.nan

# %%
hpwren_cameras_df['center_angle'] = hpwren_cameras_df.apply(lambda x: find_cl_angle( x['center_long_manual'], x['center_lat_manual'], x['long'], x['lat'], x['direction']), axis=1)
hpwren_cameras_df['camera_abbrev'] = hpwren_cameras_df.image_id.apply(lambda x: pd.Series(str(x).split("-")[0]))
hpwren_cameras_df = hpwren_cameras_df.reset_index(drop=True)

# %%
#x=.2222
#haversine((33.1599, -116.8081), (33.1599+x, -116.8081+x), unit=Unit.MILES)

def find_fov_right(direction, lat, long, fill_dist):
    #fill_dist = .2777 #25 miles away
    if direction == "north":
        return (long+fill_dist, lat+fill_dist)
    if direction == "east":
        return (long+fill_dist, lat-fill_dist)
    if direction == "south":
        return (long-fill_dist, lat-fill_dist)
    if direction == "west":
        return (long-fill_dist, lat+fill_dist)
    
def find_fov_left(direction, lat, long, fill_dist):
    #fill_dist = .2777 #25 miles away
    if direction == "north":
        return (long-fill_dist, lat+fill_dist)
    if direction == "east":
        return (long+fill_dist, lat+fill_dist)
    if direction == "south":
        return (long+fill_dist, lat-fill_dist)
    if direction == "west":
        return (long-fill_dist, lat-fill_dist)

# %%
fill_dist = .2777 #25miles out
fov_right = hpwren_cameras_df.apply(lambda x: find_fov_right(x['direction'], x['lat'], x['long'], fill_dist), axis=1)
fov_left = hpwren_cameras_df.apply(lambda x: find_fov_left(x['direction'], x['lat'], x['long'], fill_dist), axis=1)

left_edges = {'north': 'west', 'east': 'north', 'south':'east', 'west': 'south'}
right_edges = {'north': 'east', 'east':'south', 'south':'west', 'west':'north'}
intersections = []
counts = []

for i in range(len(hpwren_cameras_df)):
    direction = hpwren_cameras_df['direction'][i]
    intersection = []
    c1 = (hpwren_cameras_df['long'][i], hpwren_cameras_df['lat'][i])
    r1 = fov_right[i]
    l1 = fov_left[i]
    if (c1 != None) & (r1 != None) & (l1 != None):
        poly1 = geopandas.GeoSeries(Polygon([c1, r1, l1]))
        for j in range(len(hpwren_cameras_df)):
            c2 = (hpwren_cameras_df['long'][j], hpwren_cameras_df['lat'][j])
            r2 = fov_right[j]
            l2 = fov_left[j]
            if (c2 != None) & (r2 != None) & (l2 != None):
                poly2 = geopandas.GeoSeries(Polygon([c2, r2, l2]))
                if poly1.intersects(poly2)[0] == True:
                    if hpwren_cameras_df['camera_abbrev'][j] != hpwren_cameras_df['camera_abbrev'][i]:
                        intersection.append((hpwren_cameras_df['camera_abbrev'][j], hpwren_cameras_df['direction'][j]))
    if len(intersection) > 0:
        intersections.append(intersection)
    else:
        intersections.append(np.nan)

        
hpwren_cameras_df['intersections'] = intersections

# %%
hpwren_cameras_final_df.head()
# Out:
#                    camera_id          direction         camera_name  \
# 0  hpwren0_unknown direction  unknown direction                 NaN
# 1              hpwren1_north              north  Big Black Mountain
# 2               hpwren1_east               east  Big Black Mountain
# 3              hpwren1_south              south  Big Black Mountain
# 4               hpwren1_west               west  Big Black Mountain
#
#   camera_abbrev      image_id        long        lat  elevation geometry.type  \
# 0           tje  tje-1-mobo-c -117.120000  32.550000       10.0         Point
# 1            bm   bm-n-mobo-c -116.808092  33.159927     4055.0         Point
# 2            bm   bm-e-mobo-c -116.808092  33.159927     4055.0         Point
# 3            bm   bm-s-mobo-c -116.808092  33.159927     4055.0         Point
# 4            bm   bm-w-mobo-c -116.808092  33.159927     4055.0         Point
#
#          geometry.coordinates  x_resolution  y_resolution  center_lat  \
# 0        [-117.12, 32.55, 10]           NaN           NaN         NaN
# 1  [-116.8081, 33.1599, 4055]        3072.0        2048.0   33.181599
# 2  [-116.8081, 33.1599, 4055]        3072.0        2048.0   33.158781
# 3  [-116.8081, 33.1599, 4055]        3072.0        2048.0   33.157932
# 4  [-116.8081, 33.1599, 4055]        3072.0        2048.0   33.159091
#
#    center_long  center_angle                     properties.description.url  \
# 0          NaN           NaN        http://hpwren.ucsd.edu/cameras/TJE.html
# 1  -116.807554     -0.024816  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 2  -116.790230     -0.064085  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 3  -116.807962      0.065022  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 4  -116.858706      0.016519  http://hpwren.ucsd.edu/cameras/BBlackMtn.html
#
#                                        intersections
# 0                                                NaN
# 1  [(bl, north), (bl, east), (bh, north), (bh, ea...
# 2  [(bh, east), (bh, south), (cp, north), (cp, ea...
# 3  [(bl, east), (bl, south), (bh, south), (cp, no...
# 4  [(bl, north), (bl, east), (bl, south), (bh, so...

# %% [markdown]
# ## Select Final Columns

# %%
columns = [
    "camera_id",
    "direction",
    "camera_name",
    "camera_abbrev",
    "image_id",
    "long",
    "lat",
    "elevation",
    "geometry.type",
    "geometry.coordinates",
    "x_resolution_manual",
    "y_resolution_manual",
    "center_lat_manual",
    "center_long_manual",
    "center_angle",
    "properties.description.url",
    "intersections"
    # "properties.latest-images",
]
hpwren_cameras_final_df = hpwren_cameras_df[columns]

hpwren_cameras_final_df = hpwren_cameras_final_df.rename(
    columns={
        "x_resolution_manual": "x_resolution",
        "y_resolution_manual": "y_resolution",
        "center_lat_manual": "center_lat",
        "center_long_manual": "center_long",
    },
)

hpwren_cameras_final_df
# Out:
#                      camera_id          direction         camera_name  \
# 0    hpwren0_unknown direction  unknown direction                 NaN
# 1                hpwren1_north              north  Big Black Mountain
# 2                 hpwren1_east               east  Big Black Mountain
# 3                hpwren1_south              south  Big Black Mountain
# 4                 hpwren1_west               west  Big Black Mountain
# ..                         ...                ...                 ...
# 126       hpwren_missing5_west               west       Santiago Peak
# 127      hpwren_missing6_north              north          White Star
# 128       hpwren_missing6_east               east          White Star
# 129      hpwren_missing6_south              south          White Star
# 130       hpwren_missing6_west               west          White Star
#
#     camera_abbrev       image_id        long        lat  elevation  \
# 0             tje   tje-1-mobo-c -117.120000  32.550000       10.0
# 1              bm    bm-n-mobo-c -116.808092  33.159927     4055.0
# 2              bm    bm-e-mobo-c -116.808092  33.159927     4055.0
# 3              bm    bm-s-mobo-c -116.808092  33.159927     4055.0
# 4              bm    bm-w-mobo-c -116.808092  33.159927     4055.0
# ..            ...            ...         ...        ...        ...
# 126          stgo  stgo-w-mobo-c -117.534115  33.711172     5669.0
# 127            ws    ws-n-mobo-c -116.318014  32.647266     4000.0
# 128            ws    ws-e-mobo-c -116.318014  32.647266     4000.0
# 129            ws    ws-s-mobo-c -116.318014  32.647266     4000.0
# 130            ws    ws-w-mobo-c -116.318014  32.647266     4000.0
#
#     geometry.type        geometry.coordinates  x_resolution  y_resolution  \
# 0           Point        [-117.12, 32.55, 10]           NaN           NaN
# 1           Point  [-116.8081, 33.1599, 4055]        3072.0        2048.0
# 2           Point  [-116.8081, 33.1599, 4055]        3072.0        2048.0
# 3           Point  [-116.8081, 33.1599, 4055]        3072.0        2048.0
# 4           Point  [-116.8081, 33.1599, 4055]        3072.0        2048.0
# ..            ...                         ...           ...           ...
# 126           NaN                         NaN        3072.0        2048.0
# 127           NaN                         NaN        3072.0        2048.0
# 128           NaN                         NaN        3072.0        2048.0
# 129           NaN                         NaN        3072.0        2048.0
# 130           NaN                         NaN        3072.0        2048.0
#
#      center_lat  center_long  center_angle  \
# 0           NaN          NaN           NaN
# 1     33.181599  -116.807554     -0.024816
# 2     33.158781  -116.790230     -0.064085
# 3     33.157932  -116.807962      0.065022
# 4     33.159091  -116.858706      0.016519
# ..          ...          ...           ...
# 126   33.710503  -117.554501      0.032835
# 127   32.650875  -116.317954     -0.016515
# 128   32.646405  -116.305941     -0.071166
# 129   32.644742  -116.317985      0.011411
# 130   32.647432  -116.322302     -0.038583
#
#                         properties.description.url  \
# 0          http://hpwren.ucsd.edu/cameras/TJE.html
# 1    http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 2    http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 3    http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# 4    http://hpwren.ucsd.edu/cameras/BBlackMtn.html
# ..                                             ...
# 126                                            NaN
# 127                                            NaN
# 128                                            NaN
# 129                                            NaN
# 130                                            NaN
#
#                                          intersections
# 0                                                  NaN
# 1    [(bl, north), (bl, east), (bh, north), (bh, ea...
# 2    [(bh, east), (bh, south), (cp, north), (cp, ea...
# 3    [(bl, east), (bl, south), (bh, south), (cp, no...
# 4    [(bl, north), (bl, east), (bl, south), (bh, so...
# ..                                                 ...
# 126  [(chino, north), (chino, east), (chino, south)...
# 127  [(bm, east), (bm, south), (cp, east), (cp, sou...
# 128  [(pi, east), (ml, east), (ml, south), (mlo, ea...
# 129  [(pi, east), (pi, south), (lp, east), (lp, sou...
# 130  [(bm, south), (cp, south), (pi, north), (pi, e...
#
# [131 rows x 17 columns]

# %% [markdown]
# ## Write camera metadata to raw and processed folders

# %%
# current_time_str = datetime.now(tz=pytz.UTC).strftime("%Y%m%d_%H_%M_%S")

# hpwren cameras only
hpwren_cameras_final_df.to_csv(
    f"../../data/processed/camera_metadata_hpwren.csv", index=False
)
